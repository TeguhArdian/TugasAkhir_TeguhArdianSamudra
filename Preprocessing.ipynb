# %% [markdown]
# ### Import library yang diperlukan

# %%
import os
import cv2
from skimage.color import rgb2gray
from PIL import Image, ImageOps
import skimage.io as io
import numpy as np
import pandas as pd
import math

# %% [markdown]
# ### Lokasi file dataset yang akan digunakan

# %%
# Data normal dan glaukoma
image_folder_path ={
    'perbaikan':
    {
        'glaukoma': r"Z:\dataset\Perbaikan\Glaukoma",
        'normal': r"Z:\dataset\Perbaikan\Normal",
        'hasilg': r"Z:\dataset\Perbaikan\HasilG",
        'hasiln': r"Z:\dataset\Perbaikan\HasilN",
        'cannyg': r"Z:\dataset\Perbaikan\CannyG",
        'cannyn': r"Z:\dataset\Perbaikan\CannyN",
        'r2': r"Z:\dataset\Perbaikan\r2",
        'r3': r"Z:\dataset\Perbaikan\r3"
    },
    'bagus':
    {
        'glaukoma': r"Z:\dataset\Bagus\Ggray",
        'normal': r"Z:\dataset\Bagus\Ngray", 
        'glaukoma1': r"Z:\dataset\Bagus\G",
        'normal1': r"Z:\dataset\Bagus\N", 
        'cannyn': r"Z:\dataset\Citra2\N",
        'cannyg': r"Z:\dataset\Citra2\G",
        
    },
    'citra':
    {
        'ci': r"Z:\dataset\Citra",
        'ci2': r"Z:\dataset\Citra2"
    },
    'gabungan':
    {
        'cannyg': r"Z:\dataset\Gabungan\CannytoGray\glaukoma",
        'cannyn': r"Z:\dataset\Gabungan\CannytoGray\normal",
        'otsug': r"Z:\dataset\Gabungan\OtsutoGray\glaukoma",
        'otsun': r"Z:\dataset\Gabungan\OtsutoGray\normal",
        'otsug1': r"Z:\dataset\Gabungan\OtsutoGray\glaukoma1",
        'otsun1': r"Z:\dataset\Gabungan\OtsutoGray\normal1",
        'filternormal': r"Z:\dataset\Gabungan\normal",
        'filterglaukoma': r"Z:\dataset\Gabungan\glaukoma"
        
    },
    
    'rgb':
    {
        'r2':
        {
            'normal': r"Z:\dataset\r2\RGB\normal",
            'glaukoma': r"Z:\dataset\r2\RGB\glaukoma"
        },
        'r3':
        {
            'normal': r"Z:\dataset\r3\RGB\normal",
            'glaukoma': r"Z:\dataset\r3\RGB\glaukoma",
            'glaukoma1': r"Z:\dataset\r3\RGB\glaukoma1",
            'ganti': r"Z:\dataset\r3\RGB\ganti",
            'gantin': r"Z:\dataset\r3\RGB\gantin"
        }
    },
    'grayscale':
    {
        'r2':
        {
            'normal': r"Z:\dataset\r2\Grayscale\normal",
            'glaukoma': r"Z:\dataset\r2\Grayscale\glaukoma"
        },
        'r3':
        {
            'normal': r"Z:\dataset\r3\Grayscale\normal",
            'glaukoma': r"Z:\dataset\r3\Grayscale\glaukoma",
            'glaukoma1': r"Z:\dataset\r3\Grayscale\glaukoma1",
            'glaukoma2': r"Z:\dataset\r3\Grayscale\glaukoma2"
        }
    },
        
    'otsu':
    {
        'r2':
        {
            'normal': r"Z:\dataset\r2\Otsu\normal",
            'normal1': r"Z:\dataset\r2\Otsu\normal1",
            'glaukoma1': r"Z:\dataset\r2\Otsu\glaukoma1",
            'glaukoma': r"Z:\dataset\r2\Otsu\glaukoma"
        },
        'r3':
        {
            'normal': r"Z:\dataset\r3\Otsu\normal",
            'glaukoma': r"Z:\dataset\r3\Otsu\glaukoma",
            'normal1': r"Z:\dataset\r3\Otsu\normal1",
            'glaukoma1': r"Z:\dataset\r3\Otsu\glaukoma1"
        }
    },
    'canny':
    {
        'r2':
        {
            'normal': r"Z:\dataset\r2\Canny\normal",
            'glaukoma': r"Z:\dataset\r2\Canny\glaukoma"
        },
        'r3':
        {
            'normal': r"Z:\dataset\r3\Canny\normal",
            'glaukoma': r"Z:\dataset\r3\Canny\glaukoma"
        }
    },
    'otsutogray':
    {
        'gabungan':
        {
            'normal': r"Z:\dataset\r2\OtsutoGray\normal",
            'glaukoma': r"Z:\dataset\r2\OtsutoGray\glaukoma"
        },
        'r2':
        {
            'normal': r"Z:\dataset\r2\OtsutoGray\normal",
            'normal1': r"Z:\dataset\r2\OtsutoGray\normal1",
            'glaukoma1': r"Z:\dataset\r2\OtsutoGray\glaukoma1",
            'glaukoma': r"Z:\dataset\r2\OtsutoGray\glaukoma"
        },
        'r3':
        {
            'normal': r"Z:\dataset\r3\OtsutoGray\normal",
            'normal1': r"Z:\dataset\r3\OtsutoGray\normal1",
            'glaukoma': r"Z:\dataset\r3\OtsutoGray\glaukoma",
            'glaukoma1': r"Z:\dataset\r3\OtsutoGray\glaukoma1"
        }
    },
    'cannytogray':
    {
        'gabungan':
        {
            'normal': r"Z:\dataset\r2\CannytoGray\normal",
            'glaukoma': r"Z:\dataset\r2\CannytoGray\glaukoma"
        },
        'r2':
        {
            'normal': r"Z:\dataset\r2\CannytoGray\normal",
            'glaukoma': r"Z:\dataset\r2\CannytoGray\glaukoma"
        },
        'r3':
        {
            'normal': r"Z:\dataset\r3\CannytoGray\normal",
            'glaukoma': r"Z:\dataset\r3\CannytoGray\glaukoma"
        }
    },
}

# %%
# Data normal dan glaukoma
image_folder_path2 ={
    'mask' : r"Z:\dataset\fixdataset\R2\mask",
    'Gmask' : r"Z:\dataset\fixdataset\Mask\Glaukoma",
    'Nmask' : r"Z:\dataset\fixdataset\Mask\Normal",
    'rott':
    {
        'rgb':
        {
            'r2':
            {
                'normal' : r"Z:\dataset\fixdataset\R2\normal",
                'glaukoma': r"Z:\dataset\fixdataset\R2\glaukoma",
            },
            'r3':
            {
                'normal' : r"Z:\dataset\fixdataset\R3\normal",
                'glaukoma': r"Z:\dataset\fixdataset\R3\glaukoma",
            }
        },
        'rgbtogray': 
        {            
            'r2':
            {
                'normal' : r"Z:\dataset\fixdataset\R2\Gray\normal",
                'glaukoma': r"Z:\dataset\fixdataset\R2\Gray\glaukoma",
            },
            'r3':
            {
                'normal' : r"Z:\dataset\fixdataset\R3\Gray\normal",
                'glaukoma': r"Z:\dataset\fixdataset\R3\Gray\glaukoma",
            },
            'green':
            {
                'r2':
                {
                    'normal' : r"Z:\dataset\fixdataset\R2\Gray\green\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R2\Gray\green\glaukoma",
                },
                'r3':
                {
                    'normal' : r"Z:\dataset\fixdataset\R3\Gray\green\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R3\Gray\green\glaukoma",
                }
            },
            'clahe':
            {
                'r2':
                {
                    'normal' : r"Z:\dataset\fixdataset\R2\Gray\CLAHE\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R2\Gray\CLAHE\glaukoma",
                },
                'r3':
                {
                    'normal' : r"Z:\dataset\fixdataset\R3\Gray\CLAHE\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R3\Gray\CLAHE\glaukoma",
                }
            },
            'kontras':
            {
                'r2':
                {
                    'normal' : r"Z:\dataset\fixdataset\R2\Gray\Kontras\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R2\Gray\Kontras\glaukoma",
                },
                'r3':
                {
                    'normal' : r"Z:\dataset\fixdataset\R3\Gray\Kontras\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R3\Gray\Kontras\glaukoma",
                }
            },
            'histogram':
            {
                'r2':
                {
                    'normal' : r"Z:\dataset\fixdataset\R2\Gray\Histogram\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R2\Gray\Histogram\glaukoma",
                },
                'r3':
                {
                    'normal' : r"Z:\dataset\fixdataset\R3\Gray\Histogram\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R3\Gray\Histogram\glaukoma",
                }
            },
        },
        'canny':
        {
            'r2':
            {
                'normal' : r"Z:\dataset\fixdataset\R2\Canny\normal",
                'glaukoma': r"Z:\dataset\fixdataset\R2\Canny\glaukoma",
            },
            'r3':
            {
                'normal' : r"Z:\dataset\fixdataset\R3\Canny\normal",
                'glaukoma': r"Z:\dataset\fixdataset\R3\Canny\glaukoma",
            }
        },
        'otsu':
        {
            'r2':
            {
                'normal' : r"Z:\dataset\fixdataset\R2\Otsu\normal",
                'glaukoma': r"Z:\dataset\fixdataset\R2\Otsu\glaukoma",
            },
            'r3':
            {
                'normal' : r"Z:\dataset\fixdataset\R3\Otsu\normal",
                'glaukoma': r"Z:\dataset\fixdataset\R3\Otsu\glaukoma",
            }
        },
        'togray':
        {
            'otsu':
            {
                'r2':
                {
                    'normal' : r"Z:\dataset\fixdataset\R2\toGray\otsu\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R2\toGray\otsu\glaukoma",
                },
                'r3':
                {
                    'normal' : r"Z:\dataset\fixdataset\R3\toGray\otsu\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R3\toGray\otsu\glaukoma",
                },
                'r2r3':
                {
                    'normal' : r"Z:\dataset\fixdataset\r2r3\otsu\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\r2r3\otsu\glaukoma",
                }                
            },
            'canny':
            {
                'r2':
                {
                    'normal' : r"Z:\dataset\fixdataset\R2\toGray\canny\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R2\toGray\canny\glaukoma",
                },
                'r3':
                {
                    'normal' : r"Z:\dataset\fixdataset\R3\toGray\canny\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\R3\toGray\canny\glaukoma",
                },
                'r2r3':
                {
                    'normal' : r"Z:\dataset\fixdataset\r2r3\canny\normal",
                    'glaukoma': r"Z:\dataset\fixdataset\r2r3\canny\glaukoma",
                }                
            }
        },
    },
    
}

# %% [markdown]
# ### Enhance

# %%
from PIL import ImageEnhance
def Peningkatan(original_images_folder_path, enhance_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        rgb_images_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(enhance_images_folder_path, filename)
        
        img = Image.open(rgb_images_path)
        
        ImageBrig = ImageEnhance.Brightness(img)
        imageNew = ImageBrig.enhance(1.6)
        contrast = 1.5
        contrastImage = ImageEnhance.Contrast(imageNew)
        imageNew1 = contrastImage.enhance(contrast)
        
        #img = ImageOps.grayscale(imageNew1)
        imageNew1.save(new_image_save_path)

# %%
Peningkatan(image_folder_path['perbaikan']['glaukoma'],
            image_folder_path['perbaikan']['hasilg'])
Peningkatan(image_folder_path['perbaikan']['normal'],
            image_folder_path['perbaikan']['hasiln'])

ConvertImageRGBtoGrayscale(image_folder_path['perbaikan']['hasilg'],
                           image_folder_path['perbaikan']['cannyg'])
ConvertImageRGBtoGrayscale(image_folder_path['perbaikan']['hasiln'],
                           image_folder_path['perbaikan']['cannyn'])

CannyEdge(image_folder_path['perbaikan']['cannyg'],
          image_folder_path['perbaikan']['cannyg'])
CannyEdge(image_folder_path['perbaikan']['cannyn'],
          image_folder_path['perbaikan']['cannyn'])

# %% [markdown]
# ### Rotasi

# %%
def Rotasi(original_images_folder_path, rotasi_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        rgb_images_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(rotasi_images_folder_path, filename)
        
        img = cv2.imread(rgb_images_path, 1)
        rows,cols = img.shape[0], img.shape[1]

        img2 = cv2.getRotationMatrix2D((cols/2,rows/2),90, 1)
        imageNew1 = cv2.warpAffine(img, img2, (cols, rows))
        
        Image.fromarray(imageNew1).save(new_image_save_path)

# %%
Rotasi(image_folder_path['citra']['ci'],
       image_folder_path['citra']['ci2'])

# %%
Rotasi(image_folder_path['rott']['normalr2'],
       image_folder_path['rott']['normalr2'])
Rotasi(image_folder_path['rott']['glaukomar2'],
       image_folder_path['rott']['glaukomar2'])
Rotasi(image_folder_path['rott']['normalr3'],
       image_folder_path['rit']['ci2'])
Rotasi(image_folder_path['citra']['ci'],
       image_folder_path['citra']['ci2'])

# %% [markdown]
# ### Resize

# %%
def ResizeGambar(images_folder_path):
    for filename in os.listdir(images_folder_path):
        newimg = os.path.join(images_folder_path, filename)
        img = Image.open(newimg)
        img = img.resize((300,300))
        img.save(newimg)

# %%
ResizeGambar(image_folder_path['rott']['glaukomar2'])
ResizeGambar(image_folder_path['rott']['normalr2'])
ResizeGambar(image_folder_path['rott']['glaukomar3'])
ResizeGambar(image_folder_path['rott']['normalr3'])

# %% [markdown]
# ### Konversi RGB to Grayscale

# %%
#green channel
def RGBChan(ori_images_folder_path, rgb_image_folder_path):
    for filename in os.listdir(ori_images_folder_path):
        ori_img = os.path.join(ori_images_folder_path, filename)
        new_image_save_path = os.path.join(rgb_image_folder_path, filename)
    
        img = cv2.imread(ori_img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


        mtxR = np.zeros(((300, 300, 3)), dtype=np.integer)
        mtxG = np.zeros(((300, 300, 3)), dtype=np.integer)
        mtxB = np.zeros(((300, 300, 3)), dtype=np.integer)


        mtxR[:, :, 0] = img[:, :, 0]
        mtxG[:, :, 1] = img[:, :, 1]
        mtxB[:, :, 2] = img[:, :, 2]

        mtxR = np.asarray(mtxR, np.uint8)
        mtxG = np.asarray(mtxG, np.uint8)
        mtxB = np.asarray(mtxB, np.uint8)
        
        Image.fromarray(mtxG).save(new_image_save_path)

# %%
def ConvertImageRGBtoGrayscale(original_images_folder_path, grayscale_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        rgb_images_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(grayscale_images_folder_path, filename)
        
        img = Image.open(rgb_images_path)
        img = ImageOps.grayscale(img)
        img.save(new_image_save_path)

# %%
RGBChan(image_folder_path2['rott']['rgb']['r2']['normal'],
        image_folder_path2['rott']['rgbtogray']['green']['r2']['normal'])
RGBChan(image_folder_path2['rott']['rgb']['r2']['glaukoma'],
        image_folder_path2['rott']['rgbtogray']['green']['r2']['glaukoma'])
ConvertImageRGBtoGrayscale(image_folder_path2['rott']['rgbtogray']['green']['r2']['normal'],
                           image_folder_path2['rott']['rgbtogray']['green']['r2']['normal'])
ConvertImageRGBtoGrayscale(image_folder_path2['rott']['rgbtogray']['green']['r2']['glaukoma'], 
                           image_folder_path2['rott']['rgbtogray']['green']['r2']['glaukoma'])

RGBChan(image_folder_path2['rott']['rgb']['r3']['normal'],
        image_folder_path2['rott']['rgbtogray']['green']['r3']['normal'])
RGBChan(image_folder_path2['rott']['rgb']['r3']['glaukoma'],
        image_folder_path2['rott']['rgbtogray']['green']['r3']['glaukoma'])
ConvertImageRGBtoGrayscale(image_folder_path2['rott']['rgbtogray']['green']['r3']['normal'],
                           image_folder_path2['rott']['rgbtogray']['green']['r3']['normal'])
ConvertImageRGBtoGrayscale(image_folder_path2['rott']['rgbtogray']['green']['r3']['glaukoma'], 
                           image_folder_path2['rott']['rgbtogray']['green']['r3']['glaukoma'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   if sys.path[0] == '':
# ...

# %%
#data r2
ConvertImageRGBtoGrayscale(image_folder_path['rgb']['r2']['normal'],
                           image_folder_path['grayscale']['r2']['normal'])
ConvertImageRGBtoGrayscale(image_folder_path['rgb']['r2']['glaukoma'], 
                           image_folder_path['grayscale']['r2']['glaukoma'])

#data r3
#ConvertImageRGBtoGrayscale(image_folder_path['rgb']['r3']['normal'],
#                           image_folder_path['grayscale']['r3']['normal'])
#ConvertImageRGBtoGrayscale(image_folder_path['rgb']['r3']['glaukoma'],
#                           image_folder_path['grayscale']['r3']['glaukoma'])

# %%
ConvertImageRGBtoGrayscale(image_folder_path2['rott']['rgb']['r2']['normal'],
                           image_folder_path2['rott']['rgbtogray']['r2']['normal'])
ConvertImageRGBtoGrayscale(image_folder_path2['rott']['rgb']['r2']['glaukoma'], 
                           image_folder_path2['rott']['rgbtogray']['r2']['glaukoma'])

ConvertImageRGBtoGrayscale(image_folder_path2['rott']['rgb']['r3']['normal'],
                           image_folder_path2['rott']['rgbtogray']['r3']['normal'])
ConvertImageRGBtoGrayscale(image_folder_path2['rott']['rgb']['r3']['glaukoma'], 
                           image_folder_path2['rott']['rgbtogray']['r3']['glaukoma'])

# %%
ConvertImageRGBtoGrayscale(image_folder_path2['mask'],
                           image_folder_path2['mask'])

# %% [markdown]
# ### Perbaikan Kontras

# %%
def CLAHE(original_images_folder_path, histogram_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        rgb_images_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(histogram_images_folder_path, filename)
        
        img = cv2.imread(rgb_images_path, 0)
        clahe = cv2.createCLAHE(clipLimit =2.0, tileGridSize=(5,5))
        cl_img = clahe.apply(img)
        Image.fromarray(cl_img).save(new_image_save_path)
#        equ.save(new_image_save_path)

# %%
CLAHE(image_folder_path2['rott']['rgbtogray']['r2']['normal'],
      image_folder_path2['rott']['rgbtogray']['clahe']['r2']['normal'])
CLAHE(image_folder_path2['rott']['rgbtogray']['r2']['glaukoma'],
      image_folder_path2['rott']['rgbtogray']['clahe']['r2']['glaukoma'])

CLAHE(image_folder_path2['rott']['rgbtogray']['r3']['normal'],
      image_folder_path2['rott']['rgbtogray']['clahe']['r3']['normal'])
CLAHE(image_folder_path2['rott']['rgbtogray']['r3']['glaukoma'],
      image_folder_path2['rott']['rgbtogray']['clahe']['r3']['glaukoma'])

# %%
def Kontras(original_images_folder_path, histogram_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        rgb_images_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(histogram_images_folder_path, filename)
        
        img = cv2.imread(rgb_images_path, 0)
        original = img.copy()
      #  xp = [0, 128, 255]
      #  fp = [0, 256, 255]
        xp = [0, 64, 255] #kadar gelap (hasil eksperimen)
        fp = [0, 64, 255] #kadar terang/putih (hasil eksperimen)
        x = np.arange(256)
        table = np.interp(x, xp, fp).astype('uint8')
        img = cv2.LUT(img, table)
        Image.fromarray(img).save(new_image_save_path)
#        equ.save(new_image_save_path)

# %%
Kontras(image_folder_path2['rott']['rgbtogray']['r2']['normal'],
        image_folder_path2['rott']['rgbtogray']['kontras']['r2']['normal'])
Kontras(image_folder_path2['rott']['rgbtogray']['r2']['glaukoma'],
        image_folder_path2['rott']['rgbtogray']['kontras']['r2']['glaukoma'])

Kontras(image_folder_path2['rott']['rgbtogray']['r3']['normal'],
        image_folder_path2['rott']['rgbtogray']['kontras']['r3']['normal'])
Kontras(image_folder_path2['rott']['rgbtogray']['r3']['glaukoma'],
        image_folder_path2['rott']['rgbtogray']['kontras']['r3']['glaukoma'])

# %%
def Histogram(original_images_folder_path, histogram_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        rgb_images_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(histogram_images_folder_path, filename)
        
        img = cv2.imread(rgb_images_path, 0)
        equ = cv2.equalizeHist(img)
        Image.fromarray(equ).save(new_image_save_path)
#        equ.save(new_image_save_path)

# %%
Histogram(image_folder_path2['rott']['rgbtogray']['r2']['normal'],
          image_folder_path2['rott']['rgbtogray']['histogram']['r2']['normal'])
Histogram(image_folder_path2['rott']['rgbtogray']['r2']['glaukoma'],
          image_folder_path2['rott']['rgbtogray']['histogram']['r2']['glaukoma'])

Histogram(image_folder_path2['rott']['rgbtogray']['r3']['normal'],
          image_folder_path2['rott']['rgbtogray']['histogram']['r3']['normal'])
Histogram(image_folder_path2['rott']['rgbtogray']['r3']['glaukoma'],
          image_folder_path2['rott']['rgbtogray']['histogram']['r3']['glaukoma'])

# %% [markdown]
# ### Otsu-thresholding

# %%
def OtsuThreshold(original_images_folder_path, otsu_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        gray_image_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(otsu_images_folder_path, filename)
        
        img = cv2.imread(gray_image_path)
        grayimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ret, thresh1 = cv2.threshold(grayimg,110,255,cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        Image.fromarray(thresh1).save(new_image_save_path)

# %%
#r2
OtsuThreshold(image_folder_path['grayscale']['r2']['normal'],
              image_folder_path['otsu']['r2']['normal'])
OtsuThreshold(image_folder_path['grayscale']['r2']['glaukoma'], 
              image_folder_path['otsu']['r2']['glaukoma'])

#r3
#OtsuThreshold(image_folder_path['grayscale']['r3']['normal'],
#              image_folder_path['otsu']['r3']['normal'])
#OtsuThreshold(image_folder_path['grayscale']['r3']['glaukoma'], 
#              image_folder_path['otsu']['r3']['glaukoma'])

# %%
#otsu gray biasa
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['r2']['normal'],
              image_folder_path2['rott']['otsu']['r2']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['r2']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r2']['glaukoma'])

OtsuThreshold(image_folder_path2['rott']['rgbtogray']['r3']['normal'],
              image_folder_path2['rott']['otsu']['r3']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['r3']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r3']['glaukoma'])

# %%
#otsu green channel
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['green']['r2']['normal'],
              image_folder_path2['rott']['otsu']['r2']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['green']['r2']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r2']['glaukoma'])

OtsuThreshold(image_folder_path2['rott']['rgbtogray']['green']['r3']['normal'],
              image_folder_path2['rott']['otsu']['r3']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['green']['r3']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r3']['glaukoma'])

# %%
#otsu gray biasa -> clahe
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['clahe']['r2']['normal'],
              image_folder_path2['rott']['otsu']['r2']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['clahe']['r2']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r2']['glaukoma'])

OtsuThreshold(image_folder_path2['rott']['rgbtogray']['clahe']['r3']['normal'],
              image_folder_path2['rott']['otsu']['r3']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['clahe']['r3']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r3']['glaukoma'])

# %%
#otsu gray biasa -> peregangan kontras
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['kontras']['r2']['normal'],
              image_folder_path2['rott']['otsu']['r2']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['kontras']['r2']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r2']['glaukoma'])

OtsuThreshold(image_folder_path2['rott']['rgbtogray']['kontras']['r3']['normal'],
              image_folder_path2['rott']['otsu']['r3']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['kontras']['r3']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r3']['glaukoma'])

# %%
#otsu gray biasa -> histogram
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['histogram']['r2']['normal'],
              image_folder_path2['rott']['otsu']['r2']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['histogram']['r2']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r2']['glaukoma'])

OtsuThreshold(image_folder_path2['rott']['rgbtogray']['histogram']['r3']['normal'],
              image_folder_path2['rott']['otsu']['r3']['normal'])
OtsuThreshold(image_folder_path2['rott']['rgbtogray']['histogram']['r3']['glaukoma'], 
              image_folder_path2['rott']['otsu']['r3']['glaukoma'])

# %%
OtsuThreshold(image_folder_path2['mask'],
              image_folder_path2['mask'])
OtsuThreshold(image_folder_path2['mask'], 
              image_folder_path2['mask'])

# %% [markdown]
# ### Penghilangan background

# %%
def OtsuThresholdbg(original_images_folder_path, otsu_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        gray_image_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(otsu_images_folder_path, filename)
        
        img = cv2.imread(gray_image_path)
        grayimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ret, thresh1 = cv2.threshold(grayimg,110,255,cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        ret, thresh2 = cv2.threshold(grayimg,110,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        
        kernel = np.ones((5,5),np.uint8)
        kernel2 = np.ones((3,3),np.uint8)

        dilasi = cv2.dilate(thresh2,kernel,iterations = 9)
        erosi = cv2.erode(dilasi,kernel,iterations = 9)

        #opening = cv2.morphologyEx(thresh3,cv2.MORPH_OPEN, kernel) # morpologi opening (erosi->dilasi) 
        #closing = cv2.morphologyEx(thresh3,cv2.MORPH_CLOSE, kernel) # morpologi opening (dilasi->erosi)

        gabungan = cv2.bitwise_and(erosi, thresh1) #penggabungan dengan operasi and
        opening2 = cv2.morphologyEx(gabungan,cv2.MORPH_OPEN, kernel2) # morpologi opening (erosi->dilasi) 

        Image.fromarray(opening2).save(new_image_save_path)

# %%
# OtsutoGray(hasil_segmentasi_otsu, image_grayscale, hasil)
def maskingg(original_images_folder_path, grayscale_images_folder_path, gray_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        otsu_image_path = os.path.join(original_images_folder_path, filename)
        grayscales_image_path = os.path.join(grayscale_images_folder_path, filename)
        new_image_save_path = os.path.join(gray_images_folder_path, filename)
        
        img = cv2.imread(otsu_image_path)
        img2 = cv2.imread(grayscales_image_path)
        gabungan = cv2.bitwise_and(img, img2) #penggabungan dengan operasi and
        
        toGray = img * img2
        Image.fromarray(gabungan).save(new_image_save_path)

# %%
# backtogray(hasil segmentasi, citra grayscale, folder simpan1, folder simpan2)
def backtogray(original_images_folder_path, grayscale_images_folder_path, gray_images_folder_path, gray_images_folder_path2):
    for filename in os.listdir(original_images_folder_path):
        otsu_image_path = os.path.join(original_images_folder_path, filename)
        grayscales_image_path = os.path.join(grayscale_images_folder_path, filename)
        new_image_save_path = os.path.join(gray_images_folder_path, filename)
        new_image_save_path2 = os.path.join(gray_images_folder_path2, filename)
        
        
        img = cv2.imread(otsu_image_path)
        img2 = cv2.imread(grayscales_image_path)
        gabungan = cv2.bitwise_and(img, img2) #penggabungan dengan operasi and
        
        toGray = img * img2
        Image.fromarray(gabungan).save(new_image_save_path)
        Image.fromarray(gabungan).save(new_image_save_path2)

# %%
#penambahan mask
maskingg(image_folder_path2['rott']['otsu']['r2']['glaukoma'],
         image_folder_path2['Gmask'],
         image_folder_path2['rott']['otsu']['r2']['glaukoma'],)
maskingg(image_folder_path2['rott']['otsu']['r2']['normal'],
         image_folder_path2['Nmask'],
         image_folder_path2['rott']['otsu']['r2']['normal'],)

maskingg(image_folder_path2['rott']['otsu']['r3']['glaukoma'],
         image_folder_path2['Gmask'],
         image_folder_path2['rott']['otsu']['r3']['glaukoma'],)
maskingg(image_folder_path2['rott']['otsu']['r3']['normal'],
         image_folder_path2['Nmask'],
         image_folder_path2['rott']['otsu']['r3']['normal'],)

# %%
#back togray biasa
backtogray(image_folder_path2['rott']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['otsu']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['otsu']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)

# %%
#back togray green channel
backtogray(image_folder_path2['rott']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['green']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['otsu']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['green']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['green']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['otsu']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['green']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-73a71ef7dab9> in <module>
#       1 #back togray green channel
# ----> 2 backtogray(image_folder_path2['rott']['otsu']['r2']['glaukoma'],
#       3            image_folder_path2['rott']['rgbtogray']['green']['r2']['glaukoma'],
#       4            image_folder_path2['rott']['togray']['otsu']['r2']['glaukoma'],
#       5            image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)
#
# NameError: name 'backtogray' is not defined

# %%
#back togray -> clahe
backtogray(image_folder_path2['rott']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['clahe']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['otsu']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['clahe']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['clahe']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['otsu']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['clahe']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)

# %%
#back togray -> peregangan kontras
backtogray(image_folder_path2['rott']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['kontras']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['otsu']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['kontras']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['kontras']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['otsu']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['kontras']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)

# %%
#back togray -> histogram
backtogray(image_folder_path2['rott']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['histogram']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['otsu']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['histogram']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['histogram']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['otsu']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['histogram']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r3']['normal'],
           image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],)

# %% [markdown]
# ### Canny

# %%
def CannyEdge(original_images_folder_path, canny_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        gray_image_path = os.path.join(original_images_folder_path, filename)
        new_image_save_path = os.path.join(canny_images_folder_path, filename)
        
        img = cv2.imread(gray_image_path)
        grayimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#        edges = cv2.Canny(grayimg, 30, 70) #biasa
        edges = cv2.Canny(grayimg, 30, 60) #peragangan kontras
#        edges = cv2.Canny(grayimg, 70, 130) #clahe       
#        edges = cv2.Canny(grayimg, 60, 130) #histogram
#        edges = cv2.Canny(grayimg, 20, 50) #green

        Image.fromarray(edges).save(new_image_save_path)

# %%
#data r2
CannyEdge(image_folder_path['grayscale']['r2']['normal'],
          image_folder_path['canny']['r2']['normal'])
CannyEdge(image_folder_path['grayscale']['r2']['glaukoma'],
          image_folder_path['canny']['r2']['glaukoma'])

#data r3
#CannyEdge(image_folder_path['grayscale']['r3']['normal'],
#          image_folder_path['canny']['r3']['normal'])
#CannyEdge(image_folder_path['grayscale']['r3']['glaukoma'],
#          image_folder_path['canny']['r3']['glaukoma'])

# %%
#canny gray biasa
CannyEdge(image_folder_path2['rott']['rgbtogray']['r2']['normal'],
          image_folder_path2['rott']['canny']['r2']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['r2']['glaukoma'], 
          image_folder_path2['rott']['canny']['r2']['glaukoma'])

CannyEdge(image_folder_path2['rott']['rgbtogray']['r3']['normal'],
          image_folder_path2['rott']['canny']['r3']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['r3']['glaukoma'], 
          image_folder_path2['rott']['canny']['r3']['glaukoma'])

# %%
#canny green channel
CannyEdge(image_folder_path2['rott']['rgbtogray']['green']['r2']['normal'],
          image_folder_path2['rott']['canny']['r2']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['green']['r2']['glaukoma'], 
          image_folder_path2['rott']['canny']['r2']['glaukoma'])

CannyEdge(image_folder_path2['rott']['rgbtogray']['green']['r3']['normal'],
          image_folder_path2['rott']['canny']['r3']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['green']['r3']['glaukoma'], 
          image_folder_path2['rott']['canny']['r3']['glaukoma'])

# %%
#canny graybiasa -> clahe
CannyEdge(image_folder_path2['rott']['rgbtogray']['clahe']['r2']['normal'],
          image_folder_path2['rott']['canny']['r2']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['clahe']['r2']['glaukoma'], 
          image_folder_path2['rott']['canny']['r2']['glaukoma'])

CannyEdge(image_folder_path2['rott']['rgbtogray']['clahe']['r3']['normal'],
          image_folder_path2['rott']['canny']['r3']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['clahe']['r3']['glaukoma'], 
          image_folder_path2['rott']['canny']['r3']['glaukoma'])

# %%
#canny graybiasa -> peragangan kontras
CannyEdge(image_folder_path2['rott']['rgbtogray']['kontras']['r2']['normal'],
          image_folder_path2['rott']['canny']['r2']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['kontras']['r2']['glaukoma'], 
          image_folder_path2['rott']['canny']['r2']['glaukoma'])

CannyEdge(image_folder_path2['rott']['rgbtogray']['kontras']['r3']['normal'],
          image_folder_path2['rott']['canny']['r3']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['kontras']['r3']['glaukoma'], 
          image_folder_path2['rott']['canny']['r3']['glaukoma'])

# %%
#canny graybiasa -> ekualisasi histogram
CannyEdge(image_folder_path2['rott']['rgbtogray']['histogram']['r2']['normal'],
          image_folder_path2['rott']['canny']['r2']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['histogram']['r2']['glaukoma'], 
          image_folder_path2['rott']['canny']['r2']['glaukoma'])
maskingg(image_folder_path2['rott']['canny']['r2']['glaukoma'],
         image_folder_path2['Gmask'],
         image_folder_path2['rott']['canny']['r2']['glaukoma'],)
maskingg(image_folder_path2['rott']['canny']['r2']['normal'],
         image_folder_path2['Nmask'],
         image_folder_path2['rott']['canny']['r2']['normal'],)


CannyEdge(image_folder_path2['rott']['rgbtogray']['histogram']['r3']['normal'],
          image_folder_path2['rott']['canny']['r3']['normal'])
CannyEdge(image_folder_path2['rott']['rgbtogray']['histogram']['r3']['glaukoma'], 
          image_folder_path2['rott']['canny']['r3']['glaukoma'])
maskingg(image_folder_path2['rott']['canny']['r3']['glaukoma'],
         image_folder_path2['Gmask'],
         image_folder_path2['rott']['canny']['r3']['glaukoma'],)
maskingg(image_folder_path2['rott']['canny']['r3']['normal'],
         image_folder_path2['Nmask'],
         image_folder_path2['rott']['canny']['r3']['normal'],)

# %% [markdown]
# ### Masking canny

# %%
#masking
maskingg(image_folder_path2['rott']['canny']['r2']['glaukoma'],
         image_folder_path2['Gmask'],
         image_folder_path2['rott']['canny']['r2']['glaukoma'],)
maskingg(image_folder_path2['rott']['canny']['r2']['normal'],
         image_folder_path2['Nmask'],
         image_folder_path2['rott']['canny']['r2']['normal'],)

maskingg(image_folder_path2['rott']['canny']['r3']['glaukoma'],
         image_folder_path2['Gmask'],
         image_folder_path2['rott']['canny']['r3']['glaukoma'],)
maskingg(image_folder_path2['rott']['canny']['r3']['normal'],
         image_folder_path2['Nmask'],
         image_folder_path2['rott']['canny']['r3']['normal'],)

# %% [markdown]
# ### Bakc to grayscale canny

# %%
#back togray biasa
backtogray(image_folder_path2['rott']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['canny']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['canny']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)

# %%
#back togray green channel
backtogray(image_folder_path2['rott']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['green']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['canny']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['green']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['green']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['canny']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['green']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)

# %%
#back togray biasa -> clahe
backtogray(image_folder_path2['rott']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['clahe']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['canny']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['clahe']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['clahe']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['canny']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['clahe']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)

# %%
#back togray biasa -> peregangan kontras
backtogray(image_folder_path2['rott']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['kontras']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['canny']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['kontras']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['kontras']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['canny']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['kontras']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)

# %%
#back togray biasa -> histogram
backtogray(image_folder_path2['rott']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['histogram']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)          
backtogray(image_folder_path2['rott']['canny']['r2']['normal'],
           image_folder_path2['rott']['rgbtogray']['histogram']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)
           

backtogray(image_folder_path2['rott']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['rgbtogray']['histogram']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r3']['glaukoma'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],)           
backtogray(image_folder_path2['rott']['canny']['r3']['normal'],
           image_folder_path2['rott']['rgbtogray']['histogram']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r3']['normal'],
           image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],)

# %% [markdown]
# ### Kembalikan ke grayscale

# %%
# OtsutoGray(hasil_segmentasi_otsu, image_grayscale, hasil)
def OtsutoGray(original_images_folder_path, grayscale_images_folder_path, gray_images_folder_path):
    for filename in os.listdir(original_images_folder_path):
        otsu_image_path = os.path.join(original_images_folder_path, filename)
        grayscales_image_path = os.path.join(grayscale_images_folder_path, filename)
        new_image_save_path = os.path.join(gray_images_folder_path, filename)
        
        img = cv2.imread(otsu_image_path)
        img2 = cv2.imread(grayscales_image_path)
        gabungan = cv2.bitwise_and(img, img2) #penggabungan dengan operasi and
        
        toGray = img * img2
        Image.fromarray(gabungan).save(new_image_save_path)

# %%
#r2
OtsutoGray(image_folder_path['otsu']['r2']['normal'],
           image_folder_path['grayscale']['r2']['normal'],
           image_folder_path['otsutogray']['r2']['normal'])
OtsutoGray(image_folder_path['otsu']['r2']['glaukoma'],
           image_folder_path['grayscale']['r2']['glaukoma'],
           image_folder_path['otsutogray']['r2']['glaukoma'])

#r3
OtsutoGray(image_folder_path['otsu']['r3']['normal'],
           image_folder_path['grayscale']['r3']['normal'],
           image_folder_path['otsutogray']['r3']['normal'])
OtsutoGray(image_folder_path['otsu']['r3']['glaukoma'],
           image_folder_path['grayscale']['r3']['glaukoma'],
           image_folder_path['otsutogray']['r3']['glaukoma'])

# %%
#Canny to gray
#r2
OtsutoGray(image_folder_path['canny']['r2']['normal'],
           image_folder_path['grayscale']['r2']['normal'],
           image_folder_path['cannytogray']['r2']['normal'])
OtsutoGray(image_folder_path['canny']['r2']['glaukoma'],
           image_folder_path['grayscale']['r2']['glaukoma'],
           image_folder_path['cannytogray']['r2']['glaukoma'])

#r3
OtsutoGray(image_folder_path['canny']['r3']['normal'],
           image_folder_path['grayscale']['r3']['normal'],
           image_folder_path['cannytogray']['r3']['normal'])
OtsutoGray(image_folder_path['canny']['r3']['glaukoma'],
           image_folder_path['grayscale']['r3']['glaukoma'],
           image_folder_path['cannytogray']['r3']['glaukoma'])

# %% [markdown]
# ### GLCM

# %%
def GLCM00(dataset):
    #membentuk matriks dengan ordo nxn dengan n adalah nilai elemen terbesar dari matriks
    a,b = np.shape(dataset)
    matriks = np.zeros((np.max(dataset)+1,np.max(dataset)+1))  
    maxnilai = np.max(dataset)+1 #nilai elemen terbesar dari matriks
    for i in range(a):
        for j in range(b-1):
            matriks[dataset[i][j],dataset[i][j+1]] = matriks[dataset[i][j],dataset[i][j+1]]+1
            matriks[dataset[i][j+1],dataset[i][j]] = matriks[dataset[i][j+1],dataset[i][j]]+1
    return matriks

def GLCM45(dataset):
    a,b = np.shape(dataset)
    matriks = np.zeros((np.max(dataset)+1,np.max(dataset)+1))
    maxnilai = np.max(dataset)+1
    for i in range(a-1):
        for j in range(b-1):
            matriks[dataset[i+1][j],dataset[i][j+1]] = matriks[dataset[i+1][j],dataset[i][j+1]]+1
            matriks[dataset[i][j+1],dataset[i+1][j]] = matriks[dataset[i][j+1],dataset[i+1][j]]+1
    return matriks

def GLCM90(dataset):
    a,b = np.shape(dataset)
    matriks = np.zeros((np.max(dataset)+1,np.max(dataset)+1))
    maxnilai = np.max(dataset)+1
    for i in range(a-1):
        for j in range(b):
            matriks[dataset[i+1][j],dataset[i][j]] = matriks[dataset[i+1][j],dataset[i][j]]+1
            matriks[dataset[i][j],dataset[i+1][j]] = matriks[dataset[i][j],dataset[i+1][j]]+1
    return matriks

def GLCM135(dataset):
    a,b = np.shape(dataset)
    matriks = np.zeros((np.max(dataset)+1,np.max(dataset)+1))
    maxnilai = np.max(dataset)+1
    for i in range(a-1):
        for j in range(b-1):
            matriks[dataset[i+1][j+1],dataset[i][j]] = matriks[dataset[i+1][j+1],dataset[i][j]]+1
            matriks[dataset[i][j],dataset[i+1][j+1]] = matriks[dataset[i][j],dataset[i+1][j+1]]+1
    return matriks

def contrast(dataset):
    kontras=0
    for i in range(len(dataset)):
        for j in range(len(dataset)):
            kontras+=(i-j)**2*dataset[i][j]
    return kontras

def IDM(dataset):
    idm=0
    for i in range(len(dataset)):
        for j in range(len(dataset)):
            idm+=1/(1+(i-j)**2)*dataset[i][j]
    return idm

def entropy(dataset):
    entropi=0
    for i in range(len(dataset)):
        for j in range(len(dataset)):
            if dataset[i,j] != 0.0:
                entropi+=-dataset[i][j]*math.log(dataset[i][j],10)
    return entropi

def correlation(dataset):
    korelasi=0
    M=0
    T=0
    for i in range(len(dataset)):
        M+=i*dataset[i]
    M2 = sum(M)
    for i in range(len(dataset)):
        T+=dataset[i]*(i-M2)**2
    T2=sum(T)
    for i in range(len(dataset)):
        for j in range(len(dataset)):
            korelasi+=dataset[i][j]*(i-M2)*(j-M2)/T2**2
    return korelasi

def energy(dataset):
    energi=0
    for i in range(len(dataset)):
        for j in range(len(dataset)):
            energi+=dataset[i][j]**2
    return energi

# %%
#Normalisasi Matriks GLCM
def NormalizeGLCM(dataset):
    return dataset/sum(sum(dataset))

# %% [markdown]
# ### Statistik berbasis histogram

# %%
#rerata intensitas
def intensitas_histogram(dataset):
    #hitung frekuensi aras keabuan
    L = np.max(dataset)+2
    m,n = np.shape(dataset)
    Frek = np.zeros((L,1))
    grayimg = dataset.astype(float)
    for i in range(1,m) :
        for j in range(1,n) :
            intensitas = grayimg[i,j]
            Frek[int(intensitas+1)] = Frek[int(intensitas+1)]+1

    #hitung probabilitas
    jum_piksel = m * n
    Prob = np.zeros((L,1))
    for i in range(0,(L-1)):
        Prob[i+1]= Frek[i+1]/jum_piksel
    
    #hitung rerata intensitas
    mu = 0
    for i in range(0,(L-1)):
        #print(Prob)
        mu = mu + i * Prob[i+1]
    mu = mu[0]
    return mu
        
#deviasi standar
def standar_dev_histogram(dataset):
    #hitung frekuensi aras keabuan
    L = np.max(dataset)+2
    m,n = np.shape(dataset)
    Frek = np.zeros((L,1))
    grayimg = dataset.astype(float)
    for i in range(1,m) :
        for j in range(1,n) :
            intensitas = grayimg[i,j]
            Frek[int(intensitas+1)] = Frek[int(intensitas+1)]+1

    #hitung probabilitas
    jum_piksel = m * n
    Prob = np.zeros((L,1))
    for i in range(0,(L-1)):
        Prob[i+1]= Frek[i+1]/jum_piksel
        
    #hitung deviasi
    varians = 0
    mu = intensitas_histogram(dataset)
    for i in range(0,(L-1)):
        varians = varians + (i-mu)**2 * Prob[i+1]
    deviasi = math.sqrt(varians)
    varians_n = varians / (L-1)**2 #normalisasi
    varians_n = varians_n[0]
    return varians_n

#skewness
def skewness_histogram(dataset):
    #hitung frekuensi aras keabuan
    L = np.max(dataset)+2
    m,n = np.shape(dataset)
    Frek = np.zeros((L,1))
    grayimg = dataset.astype(float)
    for i in range(1,m) :
        for j in range(1,n) :
            intensitas = grayimg[i,j]
            Frek[int(intensitas+1)] = Frek[int(intensitas+1)]+1

    #hitung probabilitas
    jum_piksel = m * n
    Prob = np.zeros((L,1))
    for i in range(0,(L-1)):
        Prob[i+1]= Frek[i+1]/jum_piksel
        
    #menghitung skewness
    skewness = 0
    mu = intensitas_histogram(dataset)
    for i in range(0,(L-1)):
        skewness = skewness + (i-mu)**3 * Prob[i+1]
    skewness = skewness / (L-1)**2
    skewness = skewness[0]
    return skewness

#energi
def energi_histogram(dataset):
    #hitung frekuensi aras keabuan
    L = np.max(dataset)+2
    m,n = np.shape(dataset)
    Frek = np.zeros((L,1))
    grayimg = dataset.astype(float)
    for i in range(1,m) :
        for j in range(1,n) :
            intensitas = grayimg[i,j]
            Frek[int(intensitas+1)] = Frek[int(intensitas+1)]+1

    #hitung probabilitas
    jum_piksel = m * n
    Prob = np.zeros((L,1))
    for i in range(0,(L-1)):
        Prob[i+1]= Frek[i+1]/jum_piksel
        
    #menghitung energi
    energi = 0
    for i in range(0,(L-1)):
        energi = energi + Prob[i+1]**2
    energi = energi[0]
    return energi

#entropi
def entropi_histogram(dataset):
    #hitung frekuensi aras keabuan
    L = np.max(dataset)+2
    m,n = np.shape(dataset)
    Frek = np.zeros((L,1))
    grayimg = dataset.astype(float)
    for i in range(1,m) :
        for j in range(1,n) :
            intensitas = grayimg[i,j]
            Frek[int(intensitas+1)] = Frek[int(intensitas+1)]+1

    #hitung probabilitas
    jum_piksel = m * n
    Prob = np.zeros((L,1))
    for i in range(0,(L-1)):
        Prob[i+1]= Frek[i+1]/jum_piksel
        
    #menghitung entropi
    entropi = 0
    for i in range(0,(L-1)):
        if(Prob[i+1] != 0):
            entropi = entropi + Prob[i+1] * math.log(Prob[i+1])
    entropi = -entropi
    entropi = entropi[0]
    return entropi
    
#kehalusan
def kehalusan_histogram(dataset):
    varians_n = standar_dev_histogram(dataset)
    smoothness = 1 - (1 / (1+varians_n))
    return smoothness

# %% [markdown]
# ### Membuat rangka data csv

# %%
def CreateDataFrame():
    return {
        'filename' : [],
        'contrast_00' : [],
        'contrast_45' : [],
        'contrast_90' : [],
        'contrast_135' : [],
        'IDM_00' : [],
        'IDM_45' : [],
        'IDM_90' : [],
        'IDM_135' : [],
        'entropy_00' : [],
        'entropy_45' : [],
        'entropy_90' : [],
        'entropy_135' : [],
        'corellation_00' : [],
        'corellation_45' : [],
        'corellation_90' : [],
        'corellation_135' : [],
        'energy_00' : [],
        'energy_45' : [],
        'energy_90' : [],
        'energy_135' : [],
        'intensitas_histo' : [],
        'standar_dev_histo' : [],
        'skewness_histo' : [],
        'energi_histo' : [],
        'entropi_histo' : [],
        'kehalusan_histo' : [],
        
        'class' : [],
    }
dataframe = CreateDataFrame()

# %% [markdown]
# ### Ekstraksi fitur

# %%
#Main Ekstraksi
def HitungFitur(grayscale_images_folder_path, penyakit):
    for filename in os.listdir(grayscale_images_folder_path):
        filename2 = filename
        filename = os.path.join(grayscale_images_folder_path, filename)

        img = cv2.imread(filename, 0)

        dataframe['filename'].append(filename2)
        dataframe['contrast_00'].append(contrast(NormalizeGLCM(GLCM00(img))))
        dataframe['contrast_45'].append(contrast(NormalizeGLCM(GLCM45(img))))
        dataframe['contrast_90'].append(contrast(NormalizeGLCM(GLCM90(img))))
        dataframe['contrast_135'].append(contrast(NormalizeGLCM(GLCM135(img))))
        dataframe['IDM_00'].append(IDM(NormalizeGLCM(GLCM00(img))))
        dataframe['IDM_45'].append(IDM(NormalizeGLCM(GLCM45(img))))
        dataframe['IDM_90'].append(IDM(NormalizeGLCM(GLCM90(img))))
        dataframe['IDM_135'].append(IDM(NormalizeGLCM(GLCM135(img))))
        dataframe['entropy_00'].append(entropy(NormalizeGLCM(GLCM00(img))))
        dataframe['entropy_45'].append(entropy(NormalizeGLCM(GLCM45(img))))
        dataframe['entropy_90'].append(entropy(NormalizeGLCM(GLCM90(img))))
        dataframe['entropy_135'].append(entropy(NormalizeGLCM(GLCM135(img))))
        dataframe['corellation_00'].append(correlation(NormalizeGLCM(GLCM00(img))))
        dataframe['corellation_45'].append(correlation(NormalizeGLCM(GLCM45(img))))
        dataframe['corellation_90'].append(correlation(NormalizeGLCM(GLCM90(img))))
        dataframe['corellation_135'].append(correlation(NormalizeGLCM(GLCM135(img))))
        dataframe['energy_00'].append(energy(NormalizeGLCM(GLCM00(img))))
        dataframe['energy_45'].append(energy(NormalizeGLCM(GLCM45(img))))
        dataframe['energy_90'].append(energy(NormalizeGLCM(GLCM90(img))))
        dataframe['energy_135'].append(energy(NormalizeGLCM(GLCM135(img))))
        dataframe['intensitas_histo'].append(intensitas_histogram(img))
        dataframe['standar_dev_histo'].append(standar_dev_histogram(img))
        dataframe['skewness_histo'].append(skewness_histogram(img))
        dataframe['energi_histo'].append(energi_histogram(img))
        dataframe['entropi_histo'].append(entropi_histogram(img))
        dataframe['kehalusan_histo'].append(kehalusan_histogram(img))
    
    
        #img = cv2.imread(filename)
        dataframe['class'].append(penyakit)

# %% [markdown]
# ### CSV Otsu

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['otsutogray']['r2']['normal'],0)
HitungFitur(image_folder_path['otsutogray']['r2']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Otsu r2.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['otsutogray']['r3']['normal'],0)
HitungFitur(image_folder_path['otsutogray']['r3']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Otsu r3.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2+r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['gabungan']['otsun'],0)
HitungFitur(image_folder_path['gabungan']['otsug'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Otsu dataset 337.csv', index=False)

# %% [markdown]
# ### percobaan

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['otsutogray']['r3']['normal1'],0)
HitungFitur(image_folder_path['otsutogray']['r3']['glaukoma1'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('percobaan Otsu r3.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['otsutogray']['r2']['normal1'],0)
HitungFitur(image_folder_path['otsutogray']['r2']['glaukoma1'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('percobaan Otsu r2.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2+r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['gabungan']['otsun1'],0)
HitungFitur(image_folder_path['gabungan']['otsug1'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('percobaan Otsu sortir 250.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2+r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['gabungan']['filternormal'],0)
HitungFitur(image_folder_path['gabungan']['filterglaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('otsu bening.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['bagus']['normal'],0)
HitungFitur(image_folder_path['bagus']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('otsu bagus baru.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['bagus']['normal1'],0)
HitungFitur(image_folder_path['bagus']['glaukoma1'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('otsu bagus baru 370.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['bagus']['cannyn'],0)
HitungFitur(image_folder_path['bagus']['cannyg'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('canny bagus baru 370.csv', index=False)

# %% [markdown]
# ### CSV Canny

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['cannytogray']['r2']['normal'],0)
HitungFitur(image_folder_path['cannytogray']['r2']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Canny r2.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['cannytogray']['r3']['normal'],0)
HitungFitur(image_folder_path['cannytogray']['r3']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Canny r3.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2+r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['gabungan']['cannyn'],0)
HitungFitur(image_folder_path['gabungan']['cannyg'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Canny r2 r3.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['otsutogray']['training']['r2']['normal'],0)
HitungFitur(image_folder_path['otsutogray']['training']['r2']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Klasifikasi Glaukoma Filter [GLCM][Histo][R2].csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['citra']['ci'],0)
HitungFitur(image_folder_path['citra']['ci2'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Citra otsu.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r3)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path['otsutogray']['r3']['normal'],0)
HitungFitur(image_folder_path['otsutogray']['r3']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Citra r3.csv', index=False)

# %% [markdown]
# ## dataset baru

# %% [markdown]
# ### Otsu

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path2['rott']['togray']['otsu']['r2']['normal'],0)
HitungFitur(image_folder_path2['rott']['togray']['otsu']['r2']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Otsu r2 dataset asli green.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path2['rott']['togray']['otsu']['r3']['normal'],0)
HitungFitur(image_folder_path2['rott']['togray']['otsu']['r3']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Otsu r3 dataset asli green.csv', index=False)

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path2['rott']['togray']['otsu']['r2r3']['normal'],0)
HitungFitur(image_folder_path2['rott']['togray']['otsu']['r2r3']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Otsu r2r3 dataset histogram terdeteksi 400.csv', index=False)

# %% [markdown]
# ### Canny

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path2['rott']['togray']['canny']['r2']['normal'],0)
HitungFitur(image_folder_path2['rott']['togray']['canny']['r2']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Canny r2 dataset clahe.csv', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: RuntimeWarning: invalid value encountered in double_scalars

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path2['rott']['togray']['canny']['r3']['normal'],0)
HitungFitur(image_folder_path2['rott']['togray']['canny']['r3']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Canny r3 dataset clahe.csv', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: RuntimeWarning: invalid value encountered in double_scalars

# %%
#Ekstraks Fitur Training (Membuat dataframe untuk dataset r2)
dataframe = CreateDataFrame()

HitungFitur(image_folder_path2['rott']['togray']['canny']['r2r3']['normal'],0)
HitungFitur(image_folder_path2['rott']['togray']['canny']['r2r3']['glaukoma'],1)

dataframe = pd.DataFrame(data=dataframe)
dataframe.to_csv('Canny r2r3 dataset histogram terdeteksi 400.csv', index=False)
